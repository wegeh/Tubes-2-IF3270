# %%
import pandas as pd
import numpy as np
from tensorflow.keras.datasets import cifar10

# %%
(x_trainval, y_trainval), (x_test, y_test) = cifar10.load_data()

print('Train shape:', x_trainval.shape, y_trainval.shape)
print('Test shape:', x_test.shape, y_test.shape)
# Out:
# Train shape: (50000, 32, 32, 3) (50000, 1)
# Test shape: (10000, 32, 32, 3) (10000, 1)

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(
    x_trainval, y_trainval, test_size=0.2, random_state=42, stratify=y_trainval)

print(f"Train: {x_train.shape}, Val: {x_val.shape}, Test: {x_test.shape}")
# Out:
# Train: (40000, 32, 32, 3), Val: (10000, 32, 32, 3), Test: (10000, 32, 32, 3)

# %%
x_train = x_train.astype('float32') / 255.
x_val = x_val.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %%
import matplotlib.pyplot as plt

def plot_train_val_loss(history, title="Training & Validation Loss"):
    plt.figure(figsize=(8,5))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import os
import random
import numpy as np
import tensorflow as tf
from sklearn.metrics import f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, AveragePooling2D
from tensorflow.keras.optimizers import Adam

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

def build_model(input_shape, num_conv, filters, kernel_sizes, pooling_type='max'):
    model = Sequential()
    for i in range(num_conv):
        if i == 0:
            model.add(Conv2D(filters[i], kernel_sizes[i], activation='relu', input_shape=input_shape, padding='same'))
        else:
            model.add(Conv2D(filters[i], kernel_sizes[i], activation='relu', padding='same'))
        if pooling_type == 'max':
            model.add(MaxPooling2D((2,2)))
        else:
            model.add(AveragePooling2D((2,2)))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(10, activation='softmax'))
    return model

default_filters = [32, 64, 128]
default_kernel = [(3,3), (3,3), (3,3)]
default_pooling = 'max'

# Pengaruh Jumlah Layer
total_layers = 3

model = build_model(
    input_shape=(32,32,3),
    num_conv=total_layers,
    filters=default_filters,
    kernel_sizes=default_kernel,
    pooling_type=default_pooling
)
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.F1Score(average='macro', name='f1_score')]
)
history = model.fit(
    x_train, y_train, epochs=10, batch_size=64,
    validation_data=(x_val, y_val), verbose=2
)
plot_train_val_loss(history, f"Loss (Conv={total_layers})")
test_loss, test_acc, test_f1 = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")
print(f"Macro F1-Score pada test set (bawaan keras): {test_f1:.4f}")

y_pred_probs = model.predict(x_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = y_test.flatten()
macro_f1 = f1_score(y_true, y_pred, average='macro')
print(f"Macro F1-Score pada test set (library sklearn): {macro_f1:.4f}")

model.save_weights(f'weights_num_conv{total_layers}.weights.h5')
# Out:
# /Users/williamglory/Desktop/IF SEM 6/ML/Tubes-2-IF3270/.venv/lib/python3.9/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 2025-05-28 23:38:29.121289: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-05-28 23:38:29.121655: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 625/625 - 22s - 35ms/step - accuracy: 0.4401 - f1_score: 0.1954 - loss: 1.5264 - val_accuracy: 0.5810 - val_f1_score: 0.1951 - val_loss: 1.1871
# Epoch 2/10
# 625/625 - 19s - 30ms/step - accuracy: 0.6166 - f1_score: 0.1956 - loss: 1.0864 - val_accuracy: 0.6432 - val_f1_score: 0.1953 - val_loss: 1.0141
# Epoch 3/10
# 625/625 - 19s - 30ms/step - accuracy: 0.6786 - f1_score: 0.1956 - loss: 0.9167 - val_accuracy: 0.6813 - val_f1_score: 0.1956 - val_loss: 0.9157
# Epoch 4/10
# 625/625 - 21s - 34ms/step - accuracy: 0.7150 - f1_score: 0.1956 - loss: 0.8154 - val_accuracy: 0.6855 - val_f1_score: 0.1956 - val_loss: 0.9035
# Epoch 5/10
# 625/625 - 20s - 32ms/step - accuracy: 0.7430 - f1_score: 0.1956 - loss: 0.7359 - val_accuracy: 0.6969 - val_f1_score: 0.1956 - val_loss: 0.8849
# Epoch 6/10
# 625/625 - 20s - 32ms/step - accuracy: 0.7685 - f1_score: 0.1956 - loss: 0.6693 - val_accuracy: 0.7069 - val_f1_score: 0.1956 - val_loss: 0.8811
# Epoch 7/10
# 625/625 - 19s - 31ms/step - accuracy: 0.7911 - f1_score: 0.1956 - loss: 0.6042 - val_accuracy: 0.7034 - val_f1_score: 0.1955 - val_loss: 0.9112
# Epoch 8/10
# 625/625 - 20s - 33ms/step - accuracy: 0.8097 - f1_score: 0.1956 - loss: 0.5484 - val_accuracy: 0.7108 - val_f1_score: 0.1954 - val_loss: 0.9333
# Epoch 9/10
# 625/625 - 20s - 32ms/step - accuracy: 0.8242 - f1_score: 0.1956 - loss: 0.5058 - val_accuracy: 0.7063 - val_f1_score: 0.1954 - val_loss: 0.9875
# Epoch 10/10
# 625/625 - 17s - 28ms/step - accuracy: 0.8378 - f1_score: 0.1956 - loss: 0.4648 - val_accuracy: 0.6990 - val_f1_score: 0.1954 - val_loss: 1.0563
# 2025-05-28 23:41:26.621822: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-05-28 23:41:26.622097: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# Test accuracy: 0.7080
# Macro F1-Score pada test set (bawaan keras): 0.1954
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Macro F1-Score pada test set (library sklearn): 0.7080
