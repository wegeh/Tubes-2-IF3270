# %%
import pandas as pd
import numpy as np
from tensorflow.keras.datasets import cifar10

# %%
(x_trainval, y_trainval), (x_test, y_test) = cifar10.load_data()

print('Train shape:', x_trainval.shape, y_trainval.shape)
print('Test shape:', x_test.shape, y_test.shape)
# Out:
# Train shape: (50000, 32, 32, 3) (50000, 1)
# Test shape: (10000, 32, 32, 3) (10000, 1)

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(
    x_trainval, y_trainval, test_size=0.2, random_state=42, stratify=y_trainval)

print(f"Train: {x_train.shape}, Val: {x_val.shape}, Test: {x_test.shape}")
# Out:
# Train: (40000, 32, 32, 3), Val: (10000, 32, 32, 3), Test: (10000, 32, 32, 3)

# %%
x_train = x_train.astype('float32') / 255.
x_val = x_val.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %%
import matplotlib.pyplot as plt

def plot_train_val_loss(history, title="Training & Validation Loss"):
    plt.figure(figsize=(8,5))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import os
import random
import numpy as np
import tensorflow as tf
from sklearn.metrics import f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, AveragePooling2D
from tensorflow.keras.optimizers import Adam

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

def build_model(input_shape, num_conv, filters, kernel_sizes, pooling_type='max'):
    model = Sequential()
    for i in range(num_conv):
        if i == 0:
            model.add(Conv2D(filters[i], kernel_sizes[i], activation='relu', input_shape=input_shape, padding='same'))
        else:
            model.add(Conv2D(filters[i], kernel_sizes[i], activation='relu', padding='same'))
        if pooling_type == 'max':
            model.add(MaxPooling2D((2,2)))
        else:
            model.add(AveragePooling2D((2,2)))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(10, activation='softmax'))
    return model

default_filters = [32, 64, 128]
default_kernel = [(3,3), (3,3), (3,3)]
default_pooling = 'max'

# Pengaruh Jumlah Layer
total_layers = 2

model = build_model(
    input_shape=(32,32,3),
    num_conv=total_layers,
    filters=default_filters,
    kernel_sizes=default_kernel,
    pooling_type=default_pooling
)
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.F1Score(average='macro', name='f1_score')]
)
history = model.fit(
    x_train, y_train, epochs=10, batch_size=64,
    validation_data=(x_val, y_val), verbose=2
)
plot_train_val_loss(history, f"Loss (Conv={total_layers})")
test_loss, test_acc, test_f1 = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")
print(f"Macro F1-Score pada test set (bawaan keras): {test_f1:.4f}")

y_pred_probs = model.predict(x_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = y_test.flatten()
macro_f1 = f1_score(y_true, y_pred, average='macro')
print(f"Macro F1-Score pada test set (library sklearn): {macro_f1:.4f}")

model.save_weights(f'weights_num_conv{total_layers}.weights.h5')
# Out:
# /Users/williamglory/Desktop/IF SEM 6/ML/Tubes-2-IF3270/.venv/lib/python3.9/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 2025-05-28 23:39:05.877937: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-05-28 23:39:05.878298: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 625/625 - 15s - 24ms/step - accuracy: 0.4535 - f1_score: 0.1955 - loss: 1.5292 - val_accuracy: 0.5665 - val_f1_score: 0.1954 - val_loss: 1.2405
# Epoch 2/10
# 625/625 - 14s - 23ms/step - accuracy: 0.5961 - f1_score: 0.1956 - loss: 1.1493 - val_accuracy: 0.6225 - val_f1_score: 0.1955 - val_loss: 1.0831
# Epoch 3/10
# 625/625 - 15s - 25ms/step - accuracy: 0.6466 - f1_score: 0.1956 - loss: 1.0125 - val_accuracy: 0.6438 - val_f1_score: 0.1955 - val_loss: 1.0307
# Epoch 4/10
# 625/625 - 15s - 24ms/step - accuracy: 0.6772 - f1_score: 0.1956 - loss: 0.9248 - val_accuracy: 0.6562 - val_f1_score: 0.1955 - val_loss: 0.9996
# Epoch 5/10
# 625/625 - 15s - 24ms/step - accuracy: 0.7017 - f1_score: 0.1956 - loss: 0.8574 - val_accuracy: 0.6654 - val_f1_score: 0.1955 - val_loss: 0.9853
# Epoch 6/10
# 625/625 - 14s - 23ms/step - accuracy: 0.7222 - f1_score: 0.1956 - loss: 0.8018 - val_accuracy: 0.6731 - val_f1_score: 0.1955 - val_loss: 0.9679
# Epoch 7/10
# 625/625 - 14s - 22ms/step - accuracy: 0.7405 - f1_score: 0.1956 - loss: 0.7507 - val_accuracy: 0.6859 - val_f1_score: 0.1955 - val_loss: 0.9476
# Epoch 8/10
# 625/625 - 15s - 24ms/step - accuracy: 0.7574 - f1_score: 0.1956 - loss: 0.7044 - val_accuracy: 0.6861 - val_f1_score: 0.1954 - val_loss: 0.9451
# Epoch 9/10
# 625/625 - 15s - 24ms/step - accuracy: 0.7721 - f1_score: 0.1956 - loss: 0.6612 - val_accuracy: 0.6866 - val_f1_score: 0.1954 - val_loss: 0.9569
# Epoch 10/10
# 625/625 - 15s - 23ms/step - accuracy: 0.7864 - f1_score: 0.1956 - loss: 0.6243 - val_accuracy: 0.6833 - val_f1_score: 0.1954 - val_loss: 0.9764
# 2025-05-28 23:41:19.722765: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-05-28 23:41:19.723112: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# Test accuracy: 0.6888
# Macro F1-Score pada test set (bawaan keras): 0.1954
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Macro F1-Score pada test set (library sklearn): 0.6827
