# %%
import pandas as pd
import numpy as np
from tensorflow.keras.datasets import cifar10

# %%
(x_trainval, y_trainval), (x_test, y_test) = cifar10.load_data()

print('Train shape:', x_trainval.shape, y_trainval.shape)
print('Test shape:', x_test.shape, y_test.shape)
# Out:
# Train shape: (50000, 32, 32, 3) (50000, 1)
# Test shape: (10000, 32, 32, 3) (10000, 1)

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(
    x_trainval, y_trainval, test_size=0.2, random_state=42, stratify=y_trainval)

print(f"Train: {x_train.shape}, Val: {x_val.shape}, Test: {x_test.shape}")
# Out:
# Train: (40000, 32, 32, 3), Val: (10000, 32, 32, 3), Test: (10000, 32, 32, 3)

# %%
x_train = x_train.astype('float32') / 255.
x_val = x_val.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %%
import matplotlib.pyplot as plt

def plot_train_val_loss(history, title="Training & Validation Loss"):
    plt.figure(figsize=(8,5))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import os
import random
import numpy as np
import tensorflow as tf
from sklearn.metrics import f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, AveragePooling2D
from tensorflow.keras.optimizers import Adam

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

def build_model(input_shape, num_conv, filters, kernel_sizes, pooling_type='max'):
    model = Sequential()
    for i in range(num_conv):
        if i == 0:
            model.add(Conv2D(filters[i], kernel_sizes[i], activation='relu', input_shape=input_shape, padding='same'))
        else:
            model.add(Conv2D(filters[i], kernel_sizes[i], activation='relu', padding='same'))
        if pooling_type == 'max':
            model.add(MaxPooling2D((2,2)))
        else:
            model.add(AveragePooling2D((2,2)))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(10, activation='softmax'))
    return model

default_filters = [32, 64, 128]
default_kernel = [(3,3), (3,3), (3,3)]
default_pooling = 'max'

# Pengaruh Ukuran Filter
kernel_size = [(7, 7), (7, 7), (7, 7)]

model = build_model(
    input_shape=(32,32,3),
    num_conv=3,  
    filters=default_filters,  
    kernel_sizes=kernel_size,     
    pooling_type=default_pooling 
)
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.F1Score(average='macro', name='f1_score')]
)
history = model.fit(
    x_train, y_train, epochs=10, batch_size=64,
    validation_data=(x_val, y_val), verbose=2
)
plot_train_val_loss(history, f"Loss (Kernel size={kernel_size})")
test_loss, test_acc, test_f1 = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")
print(f"Macro F1-Score pada test set (bawaan keras): {test_f1:.4f}")

y_pred_probs = model.predict(x_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = y_test.flatten()
macro_f1 = f1_score(y_true, y_pred, average='macro')
print(f"Macro F1-Score pada test set (library sklearn): {macro_f1:.4f}")

model.save_weights(f'weights_kernel{"-".join([str(k[0]) for k in kernel_size])}.weights.h5')
# Out:
# Epoch 1/10
# /Users/williamglory/Desktop/IF SEM 6/ML/Tubes-2-IF3270/.venv/lib/python3.9/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-05-29 13:56:40.383388: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-05-29 13:56:40.383654: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 625/625 - 38s - 61ms/step - accuracy: 0.4177 - f1_score: 0.1955 - loss: 1.5866 - val_accuracy: 0.5252 - val_f1_score: 0.1950 - val_loss: 1.3222
# Epoch 2/10
# 625/625 - 39s - 63ms/step - accuracy: 0.5774 - f1_score: 0.1956 - loss: 1.1926 - val_accuracy: 0.6008 - val_f1_score: 0.1953 - val_loss: 1.1531
# Epoch 3/10
# 625/625 - 40s - 64ms/step - accuracy: 0.6496 - f1_score: 0.1956 - loss: 0.9970 - val_accuracy: 0.6401 - val_f1_score: 0.1956 - val_loss: 1.0332
# Epoch 4/10
# 625/625 - 40s - 64ms/step - accuracy: 0.7001 - f1_score: 0.1956 - loss: 0.8568 - val_accuracy: 0.6387 - val_f1_score: 0.1955 - val_loss: 1.0884
# Epoch 5/10
# 625/625 - 39s - 63ms/step - accuracy: 0.7417 - f1_score: 0.1956 - loss: 0.7401 - val_accuracy: 0.6443 - val_f1_score: 0.1957 - val_loss: 1.0782
# Epoch 6/10
# 625/625 - 41s - 65ms/step - accuracy: 0.7797 - f1_score: 0.1956 - loss: 0.6291 - val_accuracy: 0.6368 - val_f1_score: 0.1954 - val_loss: 1.1679
# Epoch 7/10
# 625/625 - 40s - 64ms/step - accuracy: 0.8089 - f1_score: 0.1956 - loss: 0.5431 - val_accuracy: 0.6138 - val_f1_score: 0.1954 - val_loss: 1.3017
# Epoch 8/10
# 625/625 - 40s - 64ms/step - accuracy: 0.8319 - f1_score: 0.1956 - loss: 0.4748 - val_accuracy: 0.6261 - val_f1_score: 0.1956 - val_loss: 1.3687
# Epoch 9/10
# 625/625 - 40s - 65ms/step - accuracy: 0.8550 - f1_score: 0.1956 - loss: 0.4093 - val_accuracy: 0.6277 - val_f1_score: 0.1957 - val_loss: 1.4736
# Epoch 10/10
# 625/625 - 40s - 64ms/step - accuracy: 0.8749 - f1_score: 0.1956 - loss: 0.3504 - val_accuracy: 0.6156 - val_f1_score: 0.1955 - val_loss: 1.5663
# 2025-05-29 14:02:43.299973: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-05-29 14:02:43.300259: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# Test accuracy: 0.6144
# Macro F1-Score pada test set (bawaan keras): 0.1955
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# Macro F1-Score pada test set (library sklearn): 0.6093
